# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(filepath)

# Changing the range from 2000 - 2022
df = df.drop(index=range(0, 22))
df = df.reset_index(drop=True)

display(df)

fix, ax = plt.subplots(figsize = (15,5))

year = df['year']

# Note for later: There is a space in front of the column names
extent = df[' extent']

ax.plot(year, extent, c = 'blue', linestyle = '-', marker = '.')
# Out:
#     year   mo      data-type   region   extent     area
# 0   2000   12        Goddard        N    12.64    10.96
# 1   2001   12        Goddard        N    12.49    10.55
# 2   2002   12        Goddard        N    12.61    10.64
# 3   2003   12        Goddard        N    12.59    10.80
# 4   2004   12        Goddard        N    12.55    10.98
# 5   2005   12        Goddard        N    12.23    10.56
# 6   2006   12        Goddard        N    11.95    10.17
# 7   2007   12        Goddard        N    12.03    10.18
# 8   2008   12        Goddard        N    12.36    10.97
# 9   2009   12        Goddard        N    12.20    10.59
# 10  2010   12        Goddard        N    11.83    10.43
# 11  2011   12        Goddard        N    12.15    10.63
# 12  2012   12        Goddard        N    12.01    10.45
# 13  2013   12        Goddard        N    12.18    10.87
# 14  2014   12        Goddard        N    12.35    10.89
# 15  2015   12        Goddard        N    12.04    10.64
# 16  2016   12        Goddard        N    11.46     9.62
# 17  2017   12        Goddard        N    11.74    10.26
# 18  2018   12        Goddard        N    11.86    10.45
# 19  2019   12        Goddard        N    11.90    10.52
# 20  2020   12        Goddard        N    11.73    10.16
# 21  2021   12        Goddard        N    12.15    10.74
# 22  2022   12        Goddard        N    11.89    10.27
